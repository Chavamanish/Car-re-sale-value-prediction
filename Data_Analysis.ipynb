# %%
import pandas as pd
df=pd.read_csv('new_Cardekho_dataset.csv')
df
# Out:
#                                             full_name  selling_price  \
# 0                                     Maruti Alto Std           1.20
# 1                              Hyundai Grand i10 Asta           5.50
# 2                                    Hyundai i20 Asta           2.15
# 3                       Maruti Alto K10 2010-2014 VXI           2.26
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.70
# ...                                               ...            ...
# 19626                   Toyota Platinum Etios 1.4 GXD           6.50
# 19627                          Maruti Ertiga BSIV VXI           9.25
# 19628                    Skoda Rapid 1.5 TDI Elegance           4.25
# 19629                          Mahindra XUV500 W6 2WD          12.25
# 19630                        Honda City i-VTEC CVT VX          12.00
#
#        new-price    year seller_type  km_driven   owner_type fuel_type  \
# ...

# %%
df['seller_type'].value_counts()
# Out:
# Dealer              11786
# Individual           7655
# Trustmark Dealer      190
# Name: seller_type, dtype: int64

# %%
dealer_seller_price_df=df[['seller_type','selling_price']].groupby(['seller_type']).sum()
dealer_seller_price_df['avg_selling_price']=df[['seller_type','selling_price']].groupby(['seller_type']).mean()
dealer_seller_price_df.rename(columns={'selling_price':'toal amount sold in lakhs'},inplace=True)
dealer_seller_price_df
# Out:
#                   toal amount sold in lakhs  avg_selling_price
# seller_type
# Dealer                            104329.90           8.852019
# Individual                         55642.56           7.268786
# Trustmark Dealer                    1068.26           5.622421

# %%
maruthi_prices=[]
hyundai_prices=[]
ford_prices=[]
mahindra_prices=[]
mistu_prices=[]
volvo_prices=[]
toyota_prices=[]
skoda_prices=[]
for i in range(len(df)):
    if 'Maruti' in str(df.loc[i][0]):
        #print("yes")
        maruthi_prices.append(float(df.loc[i][1]))
    elif 'Hyundai' in str(df.loc[i][0]):
        #print("yes")
        hyundai_prices.append(float(df.loc[i][1]))
    elif 'Ford' in str(df.loc[i][0]):
        ford_prices.append(df.loc[i][1]) 
    elif 'Mahindra' in str(df.loc[i][0]):
        mahindra_prices.append(df.loc[i][1]) 
    elif 'Mitsubishi' in str(df.loc[i][0]):
        mistu_prices.append(df.loc[i][1])
    elif 'Toyota' in str(df.loc[i][0]):
        toyota_prices.append(df.loc[i][1])
    elif 'Volvo' in str(df.loc[i][0]):
        volvo_prices.append(df.loc[i][1]) 
    elif 'Skoda' in str(df.loc[i][0]):
        skoda_prices.append(df.loc[i][1])

# %%
print(f'Total no.of Maruti vehicles are {len(maruthi_prices)}, Hyundai are {len(hyundai_prices)}, Ford:{len(ford_prices)}, mahindra:{len(mahindra_prices)}, mitsubushi:{len(mistu_prices)}, Toyoto:{len(toyota_prices)}, Volvo:{len(volvo_prices)}, Skoda:{len(skoda_prices)}')
# Out:
# Total no.of Maruti vehicles are 5549, Hyundai are 3559, Ford:893, mahindra:1280, mitsubushi:39, Toyoto:1144, Volvo:43, Skoda:421

# %%
import numpy as np
print(f'Avg selling price of Maruti vehicles is {np.mean(maruthi_prices)}L  Hyundai:{np.mean(hyundai_prices)}L, Ford:{np.mean(ford_prices)}L, Mahindra:{np.mean(mahindra_prices)}L, Mitsubushi:{np.mean(mistu_prices)}L, Toyota:{np.mean(toyota_prices)}L, Volvo:{np.mean(volvo_prices)}L, Skoda:{np.mean(skoda_prices)}L')
# Out:
# Avg selling price of Maruti vehicles is 6.199032258064517L  Hyundai:5.914900252880023L, Ford:6.511052631578948L, Mahindra:7.339953124999999L, Mitsubushi:10.407948717948717L, Toyota:11.721923076923078L, Volvo:25.83744186046512L, Skoda:7.547363420427554L

# %%
df['full_name'].value_counts()
# Out:
# Maruti Swift Dzire VDI              210
# Maruti Alto 800 LXI                 189
# Maruti Wagon R VXI                  164
# Maruti Swift VDI                    150
# Maruti Alto K10 VXI                 121
#                                    ...
# Mahindra Bolero Power Plus LX         1
# Ford Fiesta 1.6 Duratec S             1
# Mitsubishi Montero 3.2 GLS            1
# Volvo XC60 D4 Summum                  1
# Toyota Yaris V Optional CVT BSIV      1
# Name: full_name, Length: 3226, dtype: int64

# %%
owner_seller_price_df=df[['owner_type','selling_price']].groupby(['owner_type']).mean()
owner_seller_price_df
# Out:
#               selling_price
# owner_type
# First Owner        8.204531
# Second Owner       5.850000
# Third Owner        1.700000

# %%
fuel_transmission_df=df[['fuel_type','transmission_type','selling_price']].groupby(['fuel_type','transmission_type'],as_index=False).mean()
fuel_transmission_df
# Out:
#   fuel_type transmission_type  selling_price
# 0       CNG            Manual       4.139256
# 1    Diesel         Automatic      20.805180
# 2    Diesel            Manual       6.544845
# 3  Electric         Automatic      12.491667
# 4       LPG            Manual       9.999016
# 5    Petrol         Automatic      10.305386
# 6    Petrol            Manual       6.090482

# %%
df.corr()
# Out:
#                selling_price  new-price      year  km_driven   mileage  \
# selling_price       1.000000   0.301678  0.020935  -0.061699 -0.234956
# new-price           0.301678   1.000000  0.047371  -0.014883 -0.266306
# year                0.020935   0.047371  1.000000  -0.321015  0.260673
# km_driven          -0.061699  -0.014883 -0.321015   1.000000 -0.087813
# mileage            -0.234956  -0.266306  0.260673  -0.087813  1.000000
# engine              0.368469   0.395741 -0.062758   0.176778 -0.580518
# max_power           0.476870   0.502660  0.041910   0.019240 -0.485226
# seats               0.032844   0.065721 -0.002961   0.177458 -0.364590
#
#                  engine  max_power     seats
# selling_price  0.368469   0.476870  0.032844
# new-price      0.395741   0.502660  0.065721
# year          -0.062758   0.041910 -0.002961
# km_driven      0.176778   0.019240  0.177458
# mileage       -0.580518  -0.485226 -0.364590
# engine         1.000000   0.808725  0.483896
# ...

# %%
df.dtypes
# Out:
# full_name             object
# selling_price        float64
# new-price            float64
# year                 float64
# seller_type           object
# km_driven            float64
# owner_type            object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine               float64
# max_power            float64
# seats                  int64
# dtype: object

# %%
from sklearn import preprocessing
encode_columns=['seller_type','fuel_type','transmission_type','owner_type']
for col_name in encode_columns:
    le=preprocessing.LabelEncoder()
    df[col_name]=le.fit_transform(df[col_name])
    #print(x)

# %%
df
# Out:
#                                             full_name  selling_price  \
# 0                                     Maruti Alto Std           1.20
# 1                              Hyundai Grand i10 Asta           5.50
# 2                                    Hyundai i20 Asta           2.15
# 3                       Maruti Alto K10 2010-2014 VXI           2.26
# 4      Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.70
# ...                                               ...            ...
# 19626                   Toyota Platinum Etios 1.4 GXD           6.50
# 19627                          Maruti Ertiga BSIV VXI           9.25
# 19628                    Skoda Rapid 1.5 TDI Elegance           4.25
# 19629                          Mahindra XUV500 W6 2WD          12.25
# 19630                        Honda City i-VTEC CVT VX          12.00
#
#        new-price    year  seller_type  km_driven  owner_type  fuel_type  \
# ...

# %%
df.dtypes
# Out:
# full_name             object
# selling_price        float64
# new-price            float64
# year                 float64
# seller_type            int64
# km_driven            float64
# owner_type             int64
# fuel_type              int64
# transmission_type      int64
# mileage              float64
# engine               float64
# max_power            float64
# seats                  int64
# dtype: object

# %%
#from sklearn.model_selection import train_test_split,GridSearchCV
x=df.drop(['full_name','selling_price','new-price','seller_type'],axis='columns',inplace=False)
y=df['selling_price']
#from imblearn.over_sampling import SMOTE
#smote = SMOTE(sampling_strategy='not majority',k_neighbors=1)
#x_sm,y_sm = smote.fit_resample(x,y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
#print(x_train.shape,y_train.shape)

# %%
import sklearn
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier as knn
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score,r2_score
from sklearn.linear_model import LinearRegression

# %%
linear_classifier = LinearRegression()
linear_classifier.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear_classifier.coef_
# Out:
# array([ 2.38790714e-02, -1.31136070e-05, -2.93349649e+00, -5.50899662e-01,
#        -3.22743706e+00, -1.55005335e-01, -8.58801593e-04,  1.01338173e-01,
#        -4.17518729e-01])

# %%
linear_classifier.intercept_
# Out:
# -38.94375135968652

# %%
predictions = linear_classifier.predict(x_test)

# %%
score = r2_score(y_test,predictions)
print(score)
# Out:
# 0.20739257717337067

# %%
from statsmodels.api import OLS

model= OLS(y_train, x_train).fit()
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:          selling_price   R-squared (uncentered):                   0.535
# Model:                            OLS   Adj. R-squared (uncentered):              0.535
# Method:                 Least Squares   F-statistic:                              1758.
# Date:                Sun, 07 Nov 2021   Prob (F-statistic):                        0.00
# Time:                        21:12:09   Log-Likelihood:                         -49755.
# No. Observations:               13741   AIC:                                  9.953e+04
# Df Residuals:                   13732   BIC:                                  9.960e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...
